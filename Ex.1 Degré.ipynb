# %%
import pandas as pd
data = pd.read_csv("celsius.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   celsius     7 non-null      int64
#  1   fahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 240.0 bytes

# %% [markdown]
# Info sur le set

# %%
data.head()
# Out:
#    celsius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
# ...

# %%
import seaborn as sb

# %%
sb.scatterplot(x="celsius",y="fahrenheit",data=data, hue="fahrenheit", palette="coolwarm")
# Out:
# <Axes: xlabel='celsius', ylabel='fahrenheit'>

# %%
X = data["celsius"]
X
# Out:
# 0   -40
# 1   -10
# 2     0
# 3     8
# 4    15
# 5    22
# 6    38
# Name: celsius, dtype: int64

# %%
Y = data["fahrenheit"]
Y
# Out:
# 0    -40.0
# 1     14.0
# 2     32.0
# 3     46.4
# 4     59.0
# 5     71.6
# 6    100.4
# Name: fahrenheit, dtype: float64

# %%
X = data["celsius"]
Y = data["fahrenheit"]
X, Y
# Out:
# (0   -40
#  1   -10
#  2     0
#  3     8
#  4    15
#  5    22
#  6    38
#  Name: celsius, dtype: int64,
#  0    -40.0
#  1     14.0
#  2     32.0
#  3     46.4
#  4     59.0
#  5     71.6
#  6    100.4
#  Name: fahrenheit, dtype: float64)

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %%
X.values.reshape(-1, 1)
# Out:
# array([[-40],
#        [-10],
#        [  0],
#        [  8],
#        [ 15],
#        [ 22],
#        [ 38]])

# %%
Y.values.reshape(-1, 1)
# Out:
# array([[-40. ],
#        [ 14. ],
#        [ 32. ],
#        [ 46.4],
#        [ 59. ],
#        [ 71.6],
#        [100.4]])

# %%
x_proccessed = X.values.reshape(-1, 1)
y_proccessed = Y.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_proccessed, y_proccessed)
# Out:
# LinearRegression()

# %%
model.predict([[555]])
# Out:
# array([[1031.]])

# %%
model.score(x_proccessed, y_proccessed)
# Out:
# 1.0
